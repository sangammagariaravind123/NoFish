# %%
# !python -version
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files (x86)/msys2/ucrt64/bin/python.exe" -m pip install ipykernel -U --user --force-reinstall'
